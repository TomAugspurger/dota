# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from dota import api
from dota.helpers import cached_games

# %%
datapath = Path(os.path.expanduser('~/sandbox/dota/data/'))
games = (datapath / Path(str(x) + '.json') for x in cached_games(datapath))

# %%
drs = [api.DetailsResponse.from_json(str(x)) for x in games]

# %%
drs
