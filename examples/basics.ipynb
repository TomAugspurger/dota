# %%
# %load_ext autoreload
# %autoreload

import arrow
import json
import requests
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from dota import api

# %%
# supply your own API key.
with open('/Users/admin/Dropbox/bin/api-keys.txt', 'r') as f:
    api_keys = json.load(f)

KEY = api_keys['steam']  # just a string with the key.
account_id = "76561198025007092"

h = api.API(KEY)

# %%
history = h.get_match_history(account_id=account_id)
history.get_partners().head()
# Out:
# 64741364     140
# 142531084     45
# 99913128       2
# 51777718       2
# 145551507      2
# dtype: int64

# %%
details = history.get_all_match_details()
# Out:
# Added 540387196 (0.0%)
# Added 533408126 (1.0%)
# Added 526809506 (2.0%)
# Added 511081210 (3.0%)
# Added 486050019 (4.0%)
# Added 474832262 (5.0%)
# Added 469304625 (6.0%)
# Added 465041243 (7.0%)
# Added 458081980 (8.0%)
# Added 450750719 (9.0%)

# %%
details[526809506].get_match_report()
# Out:
#                                   level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 526809506 Radiant death_prophet      19     11       3        9         81
#                   witch_doctor       17     12       1       20         49
#                   sand_king          15      3       3       21         56
#                   phantom_lancer     18     10       1       10        208
#                   110                18     12       1       22         24
#           Dire    earthshaker        10      1      14        3         22
#                   medusa             11      1       7        2         54
#                   brewmaster         13      1       7        2         57
#                   shadow_shaman      12      0      11        4         63
#                   mirana             12      2       9        1         67
#
#                                   denies  gold  gold_spent  team  account_id  \
# match_id  team    hero
# 526809506 Radiant death_prophet        1  3326       12495     2  4294967295
#                   witch_doctor         0  5044        9510     1  4294967295
#                   sand_king            1  1309       10220     3   142531084
#                   phantom_lancer       3  4162       17610     4    64741364
#                   110                  3  3272       11145     0   102191207
#           Dire    earthshaker          0   903        3580   131  4294967295
#                   medusa               2   687        6170   130  4294967295
#                   brewmaster           1   795        5480   132  4294967295
#                   shadow_shaman        2   730        7125   129  4294967295
#                   mirana               2   193        7235   128    87496722
#
#                                   item_0  item_1  item_2  item_3  item_4  \
# match_id  team    hero
# 526809506 Radiant death_prophet      121     102      36      48      41
#                   witch_doctor       108      16     180     152       0
#                   sand_king          180     108      73       1       0
#                   phantom_lancer     114      46      63     174     147
#                   110                114      92     102       0     214
#           Dire    earthshaker         44     182      38     180      92
#                   medusa              24      11      50      69       0
#                   brewmaster          50      81      16     182      60
#                   shadow_shaman      180      28     185      77       0
#                   mirana               0     168       0       0       0
#
#                                   item_5    win
# match_id  team    hero
# 526809506 Radiant death_prophet        0   True
#                   witch_doctor         0   True
#                   sand_king            0   True
#                   phantom_lancer     178   True
#                   110                  0   True
#           Dire    earthshaker          0  False
#                   medusa               0  False
#                   brewmaster           0  False
#                   shadow_shaman       69  False
#                   mirana               0  False
#
# [10 rows x 17 columns]

# %%
JOESID = 142531084
my_dota_id = api.id_32(int(account_id))

# %%
df = pd.concat([details[m].get_match_report() for m in details])
df.head()
# Out:
#                                   level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 480276736 Radiant lone_druid         25      7       8       14        293
#                   sniper             25     17       9       13        299
#                   riki               25     13      11       18         89
#                   crystal_maiden     19      4      18        9         78
#                   shredder           25      9      12       11        236
#
#                                   denies  gold  gold_spent  team  account_id  \
# match_id  team    hero
# 480276736 Radiant lone_druid           3  1029       21054     0    64741364
#                   sniper              20  1726       25140     2   122320847
#                   riki                 0  1479       13961     1  4294967295
#                   crystal_maiden       0   359       11570     3    70170480
#                   shredder             2  3752       19594     4    65048379
#
#                                   item_0  item_1  item_2  item_3  item_4  \
# match_id  team    hero
# 480276736 Radiant lone_druid          36     214       0       0     182
#                   sniper              63     116     168     154     141
#                   riki               147      63     125     154       0
#                   crystal_maiden      79      21     214       8       1
#                   shredder           152     180     121     116     168
#
#                                   item_5    win
# match_id  team    hero
# 480276736 Radiant lone_druid          43  False
#                   sniper             164  False
#                   riki                 0  False
#                   crystal_maiden      26  False
#                   shredder            30  False
#
# [5 rows x 17 columns]

# %%
# my win percent
df[df.account_id == my_dota_id].win.mean()
# Out:
# 0.59285714285714286

# %%
# Joe's win percent
df[df.account_id == JOESID].win.mean()
# Out:
# 0.53333333333333333

# %%
gr = df.groupby(level='match_id')
games = gr['account_id'].apply(lambda x:
                              (my_dota_id in x.values) &
                              (JOESID in x.values))
games = games[games].index

idx_names =  df.index.names
df = df.reset_index()
joint = df[df.match_id.isin(games)]
joint = joint.set_index(idx_names)
df = df.set_index(idx_names)

joint.head()
# Out:
#                                        level  kills  deaths  assists  \
# match_id  team    hero
# 526924586 Radiant broodmother             13      6       7        9
#                   104                     16      8       6       19
#                   keeper_of_the_light     16      4       3       16
#                   treant                  14      5       5        6
#                   axe                     18     18       7       15
#
#                                        last_hits  denies  gold  gold_spent  \
# match_id  team    hero
# 526924586 Radiant broodmother                 63       0  2735        7770
#                   104                         51       0  3077        8985
#                   keeper_of_the_light         65       1  2867        8760
#                   treant                      24       5  1746        9540
#                   axe                         83       1  1088       14960
#
#                                        player_slot  account_id  item_0  \
# match_id  team    hero
# 526924586 Radiant broodmother                    4  4294967295      36
#                   104                            3   122320847      63
#                   keeper_of_the_light            0   142531084      24
#                   treant                         1    64741364      92
#                   axe                            2   105647762     127
#
#                                        item_1  item_2  item_3  item_4  item_5  \
# match_id  team    hero
# 526924586 Radiant broodmother              63      98     178      44       0
#                   104                     152     168       0       0       0
#                   keeper_of_the_light      46     214     102      79       0
#                   treant                   36     100     131      46     180
#                   axe                      48     125       0     114       0
#
#                                         win
# match_id  team    hero
# 526924586 Radiant broodmother          True
#                   104                  True
#                   keeper_of_the_light  True
#                   treant               True
#                   axe                  True
#
# [5 rows x 17 columns]

# %%
joint.win.mean()
# Out:
# 0.5

# %%
import datetime

df.to_csv('details_joined-' + datetime.datetime.now().strftime('%Y-%m-%d'))

# %%
for k, v in details.items():
    with open('details/detail' + str(k) + '.json', 'w') as f:
        json.dump(v.resp, f)
