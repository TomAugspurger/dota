# %%
# %load_ext autoreload
# %autoreload

import arrow
import json
import os

import requests
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

from dota import api
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# supply your own API key.
with open(os.path.expanduser('~/Dropbox/bin/api-keys.txt'), 'r') as f:
    api_keys = json.load(f)

KEY = api_keys['steam']  # just a string with the key.
account_id = "76561198025007092"

h = api.API(KEY)

# %%
history = h.get_match_history(account_id=account_id)
history.partner_counts().head()
# Out:
# 64741364     158
# 142531084     49
# 36947763       2
# 145551507      2
# 86047172       2
# dtype: int64

# %%
details = history.get_all_match_details()
# Out:
# Added 550062218 (0.0%)
# Added 541698504 (10.126582278481013%)
# Added 533444058 (19.620253164556964%)
# Added 533408126 (20.253164556962027%)
# Added 525602243 (29.746835443037973%)
# Added 525553478 (30.379746835443036%)
# Added 510739148 (39.87341772151899%)
# Added 480276736 (50.0%)
# Added 471833055 (60.12658227848101%)
# Added 466847536 (69.62025316455696%)
# Added 466813579 (70.25316455696202%)
# Added 459824629 (79.74683544303798%)
# Added 459783808 (80.37974683544304%)
# Added 453225946 (89.87341772151899%)

# %%
details[526809506].match_report()
# Out:
#                                   level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 526809506 Radiant witch_doctor       17     12       1       20         49
#                   death_prophet      19     11       3        9         81
#                   phantom_lancer     18     10       1       10        208
#                   sand_king          15      3       3       21         56
#                   110                18     12       1       22         24
#           Dire    mirana             12      2       9        1         67
#                   shadow_shaman      12      0      11        4         63
#                   brewmaster         13      1       7        2         57
#                   medusa             11      1       7        2         54
#                   earthshaker        10      1      14        3         22
#
#                                   denies  gold  gold_spent  player_slot  \
# match_id  team    hero
# 526809506 Radiant witch_doctor         0  5044        9510            1
#                   death_prophet        1  3326       12495            2
#                   phantom_lancer       3  4162       17610            4
#                   sand_king            1  1309       10220            3
#                   110                  3  3272       11145            0
#           Dire    mirana               2   193        7235          128
#                   shadow_shaman        2   730        7125          129
#                   brewmaster           1   795        5480          132
#                   medusa               2   687        6170          130
#                   earthshaker          0   903        3580          131
#
#                                   account_id  item_0  item_1  item_2  item_3  \
# match_id  team    hero
# 526809506 Radiant witch_doctor           NaN     108      16     180     152
#                   death_prophet          NaN     121     102      36      48
#                   phantom_lancer    64741364     114      46      63     174
#                   sand_king        142531084     180     108      73       1
#                   110              102191207     114      92     102       0
#           Dire    mirana            87496722       0     168       0       0
#                   shadow_shaman          NaN     180      28     185      77
#                   brewmaster             NaN      50      81      16     182
#                   medusa                 NaN      24      11      50      69
#                   earthshaker            NaN      44     182      38     180
#
#                                   item_4  item_5    win
# match_id  team    hero
# 526809506 Radiant witch_doctor         0       0   True
#                   death_prophet       41       0   True
#                   phantom_lancer     147     178   True
#                   sand_king            0       0   True
#                   110                214       0   True
#           Dire    mirana               0       0  False
#                   shadow_shaman        0      69  False
#                   brewmaster          60       0  False
#                   medusa               0       0  False
#                   earthshaker         92       0  False
#
# [10 rows x 17 columns]

# %%
JOESID = 142531084
my_dota_id = api.id_32(int(account_id))
joes_steam = api.id_64(JOESID)

# %%
df = pd.concat([details[m].match_report() for m in details])
df.head()
# Out:
#                                   level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 480276736 Radiant riki               25     13      11       18         89
#                   sniper             25     17       9       13        299
#                   crystal_maiden     19      4      18        9         78
#                   lone_druid         25      7       8       14        293
#                   shredder           25      9      12       11        236
#
#                                   denies  gold  gold_spent  player_slot  \
# match_id  team    hero
# 480276736 Radiant riki                 0  1479       13961            1
#                   sniper              20  1726       25140            2
#                   crystal_maiden       0   359       11570            3
#                   lone_druid           3  1029       21054            0
#                   shredder             2  3752       19594            4
#
#                                   account_id  item_0  item_1  item_2  item_3  \
# match_id  team    hero
# 480276736 Radiant riki                   NaN     147      63     125     154
#                   sniper           122320847      63     116     168     154
#                   crystal_maiden    70170480      79      21     214       8
#                   lone_druid        64741364      36     214       0       0
#                   shredder          65048379     152     180     121     116
#
#                                   item_4  item_5    win
# match_id  team    hero
# 480276736 Radiant riki                 0       0  False
#                   sniper             141     164  False
#                   crystal_maiden       1      26  False
#                   lone_druid         182      43  False
#                   shredder           168      30  False
#
# [5 rows x 17 columns]

# %%
# my win percent
df[df.account_id == my_dota_id].win.mean()
# Out:
# 0.57594936708860756

# %%
# Win percent with Joe
df[df.account_id == JOESID].win.mean()
# Out:
# 0.53061224489795922

# %%
gr = df.groupby(level='match_id')
games = gr['account_id'].apply(lambda x:
                              (my_dota_id in x.values) &
                              (JOESID in x.values))
games = games[games].index

idx_names =  df.index.names
df = df.reset_index()
joint = df[df.match_id.isin(games)]
joint = joint.set_index(idx_names)
df = df.set_index(idx_names)

joint.head()
# Out:
#                               level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 546195205 Radiant omniknight     18      3       7       10         49
#                   weaver         20      8       7       15        142
#                   spectre        21      4      12       17        111
#                   windrunner     22     11       5       16        160
#                   viper          21      6       6       12        178
#
#                               denies  gold  gold_spent  player_slot  \
# match_id  team    hero
# 546195205 Radiant omniknight      23  3564        9005            2
#                   weaver           6  4621       15030            3
#                   spectre          4  1673       16075            0
#                   windrunner       3  4422       17385            1
#                   viper           15  3530       16935            4
#
#                               account_id  item_0  item_1  item_2  item_3  \
# match_id  team    hero
# 546195205 Radiant omniknight         NaN     180      79     178       9
#                   weaver       142531084      63     212     168      32
#                   spectre      126801707      50      11     114      65
#                   windrunner         NaN     152       7       7     141
#                   viper         64741364      50      46     185     108
#
#                               item_4  item_5   win
# match_id  team    hero
# 546195205 Radiant omniknight       0       0  True
#                   weaver         123      30  True
#                   spectre        127       0  True
#                   windrunner     164      63  True
#                   viper           52     116  True
#
# [5 rows x 17 columns]

# %%
joint.win.mean()
# Out:
# 0.5

# %%
import datetime

df.to_csv('../data/details_joined-' + datetime.datetime.now().strftime('%Y-%m-%d'))

# %%
for k, v in details.items():
    with open('../data/detail' + str(k) + '.json', 'w') as f:
        json.dump(v.resp, f)

# %%
# Joe's data

steam_id = api.id_64(142531084)
joe_hist = h.get_match_history(account_id=steam_id)
details = joe_hist.get_all_match_details()
# Out:
# Added 550037822 (0.0%)
# Added 550014092 (0.2%)
# Added 548780514 (0.4%)
# Added 530054192 (9.6%)
# Added 530034680 (9.8%)
# Added 528314084 (10.0%)
# Added 528276599 (10.2%)
# Added 526978510 (10.4%)
# Added 494192603 (19.6%)
# Added 492408049 (19.8%)
# Added 490424342 (20.0%)
# Added 488885955 (20.2%)
# Added 487444215 (20.4%)
# Added 468071052 (29.6%)
# Added 467640267 (29.8%)
# Added 466847536 (30.0%)
# Added 466813579 (30.2%)
# Added 466787253 (30.4%)
# Added 453662179 (39.6%)
# Added 453659416 (39.8%)
# Added 453626436 (40.0%)
# Added 453424938 (40.2%)
# Added 453346070 (40.4%)
# Added 434674901 (49.6%)
# Added 433379320 (49.8%)
# Added 433317133 (50.0%)
# Added 433210652 (50.2%)
# Added 433123686 (50.4%)
# Added 418395806 (59.6%)
# Added 417495200 (59.8%)
# Added 417421662 (60.0%)
# Added 417373757 (60.2%)
# Added 417337096 (60.4%)
# Added 402121381 (69.6%)
# Added 402097237 (69.8%)
# Added 402044535 (70.0%)
# Added 402016353 (70.2%)
# Added 401111775 (70.4%)
# Added 385699276 (79.6%)
# Added 385523515 (79.8%)
# Added 385511908 (80.0%)
# Added 385454704 (80.2%)
# Added 383925673 (80.4%)
# Added 368991886 (89.6%)
# Added 368925474 (89.8%)
# Added 367903256 (90.0%)
# Added 367839135 (90.2%)
# Added 367830558 (90.4%)
# Added 354222605 (99.6%)
# Added 354220703 (99.8%)

# %%
details[max(details)].resp
# Out:
# {'players': [{'gold_per_min': 379,
#    'player_slot': 0,
#    'hero_damage': 7767,
#    'level': 16,
#    'account_id': nan,
#    'xp_per_min': 387,
#    'leaver_status': 0,
#    'hero_id': 75,
#    'item_2': 206,
#    'deaths': 4,
#    'gold': 4045,
#    'denies': 3,
#    'kills': 4,
#    'hero_healing': 1933,
#    'ability_upgrades': [{'ability': 5379, 'time': 167, 'level': 1},
#     {'ability': 5377, 'time': 303, 'level': 2},
#     {'ability': 5378, 'time': 393, 'level': 3},
#     {'ability': 5377, 'time': 543, 'level': 4},
#     {'ability': 5377, 'time': 683, 'level': 5},
#     {'ability': 5380, 'time': 1028, 'level': 6},
#     {'ability': 5377, 'time': 1120, 'level': 7},
#     {'ability': 5379, 'time': 1146, 'level': 8},
#     {'ability': 5379, 'time': 1363, 'level': 9},
#     {'ability': 5379, 'time': 1531, 'level': 10},
#     {'ability': 5380, 'time': 1574, 'level': 11},
#     {'ability': 5378, 'time': 1741, 'level': 12},
#     {'ability': 5378, 'time': 1826, 'level': 13},
#     {'ability': 5378, 'time': 2058, 'level': 14},
#     {'ability': 5002, 'time': 2207, 'level': 15},
#     {'ability': 5380, 'time': 2351, 'level': 16}],
#    'tower_damage': 1880,
#    'assists': 10,
#    'item_3': 79,
#    'last_hits': 66,
#    'item_1': 36,
#    'item_0': 102,
#    'gold_spent': 10560,
#    'item_5': 77,
#    'item_4': 63},
#   {'gold_per_min': 319,
#    'player_slot': 1,
#    'hero_damage': 4914,
#    'level': 15,
#    'account_id': 64741364,
#    'xp_per_min': 329,
#    'leaver_status': 0,
#    'hero_id': 102,
#    'item_2': 102,
#    'deaths': 5,
#    'gold': 2841,
#    'denies': 4,
#    'kills': 4,
#    'hero_healing': 2437,
#    'ability_upgrades': [{'ability': 5586, 'time': 157, 'level': 1},
#     {'ability': 5585, 'time': 330, 'level': 2},
#     {'ability': 5585, 'time': 371, 'level': 3},
#     {'ability': 5586, 'time': 495, 'level': 4},
#     {'ability': 5586, 'time': 684, 'level': 5},
#     {'ability': 5588, 'time': 1001, 'level': 6},
#     {'ability': 5585, 'time': 1087, 'level': 7},
#     {'ability': 5586, 'time': 1404, 'level': 8},
#     {'ability': 5585, 'time': 1671, 'level': 9},
#     {'ability': 5587, 'time': 1800, 'level': 10},
#     {'ability': 5588, 'time': 1817, 'level': 11},
#     {'ability': 5587, 'time': 2123, 'level': 12},
#     {'ability': 5587, 'time': 2123, 'level': 13},
#     {'ability': 5587, 'time': 2353, 'level': 14},
#     {'ability': 5002, 'time': 2440, 'level': 15}],
#    'tower_damage': 802,
#    'assists': 17,
#    'item_3': 46,
#    'last_hits': 18,
#    'item_1': 36,
#    'item_0': 180,
#    'gold_spent': 9100,
#    'item_5': 0,
#    'item_4': 185},
#   {'gold_per_min': 550,
#    'player_slot': 2,
#    'hero_damage': 21967,
#    'level': 22,
#    'account_id': 142531084,
#    'xp_per_min': 683,
#    'leaver_status': 0,
#    'hero_id': 44,
#    'item_2': 0,
#    'deaths': 3,
#    'gold': 2941,
#    'denies': 8,
#    'kills': 18,
#    'hero_healing': 0,
#    'ability_upgrades': [{'ability': 5190, 'time': 166, 'level': 1},
#     {'ability': 5192, 'time': 327, 'level': 2},
#     {'ability': 5190, 'time': 378, 'level': 3},
#     {'ability': 5192, 'time': 448, 'level': 4},
#     {'ability': 5190, 'time': 551, 'level': 5},
#     {'ability': 5193, 'time': 676, 'level': 6},
#     {'ability': 5191, 'time': 797, 'level': 7},
#     {'ability': 5190, 'time': 850, 'level': 8},
#     {'ability': 5191, 'time': 964, 'level': 9},
#     {'ability': 5191, 'time': 1073, 'level': 10},
#     {'ability': 5193, 'time': 1149, 'level': 11},
#     {'ability': 5191, 'time': 1415, 'level': 12},
#     {'ability': 5192, 'time': 1496, 'level': 13},
#     {'ability': 5192, 'time': 1557, 'level': 14},
#     {'ability': 5002, 'time': 1657, 'level': 15},
#     {'ability': 5193, 'time': 1836, 'level': 16},
#     {'ability': 5002, 'time': 1981, 'level': 17},
#     {'ability': 5002, 'time': 2127, 'level': 18},
#     {'ability': 5002, 'time': 2224, 'level': 19},
#     {'ability': 5002, 'time': 2224, 'level': 20},
#     {'ability': 5002, 'time': 2348, 'level': 21},
#     {'ability': 5002, 'time': 2439, 'level': 22}],
#    'tower_damage': 3174,
#    'assists': 14,
#    'item_3': 50,
#    'last_hits': 98,
#    'item_1': 112,
#    'item_0': 145,
#    'gold_spent': 17615,
#    'item_5': 0,
#    'item_4': 135},
#   {'gold_per_min': 527,
#    'player_slot': 3,
#    'hero_damage': 13333,
#    'level': 20,
#    'account_id': nan,
#    'xp_per_min': 563,
#    'leaver_status': 0,
#    'hero_id': 52,
#    'item_2': 108,
#    'deaths': 6,
#    'gold': 3930,
#    'denies': 0,
#    'kills': 9,
#    'hero_healing': 285,
#    'ability_upgrades': [{'ability': 5243, 'time': 261, 'level': 1},
#     {'ability': 5242, 'time': 302, 'level': 2},
#     {'ability': 5243, 'time': 398, 'level': 3},
#     {'ability': 5241, 'time': 487, 'level': 4},
#     {'ability': 5242, 'time': 561, 'level': 5},
#     {'ability': 5244, 'time': 690, 'level': 6},
#     {'ability': 5242, 'time': 819, 'level': 7},
#     {'ability': 5242, 'time': 963, 'level': 8},
#     {'ability': 5241, 'time': 1163, 'level': 9},
#     {'ability': 5243, 'time': 1221, 'level': 10},
#     {'ability': 5244, 'time': 1316, 'level': 11},
#     {'ability': 5241, 'time': 1494, 'level': 12},
#     {'ability': 5243, 'time': 1544, 'level': 13},
#     {'ability': 5241, 'time': 1745, 'level': 14},
#     {'ability': 5002, 'time': 1776, 'level': 15},
#     {'ability': 5244, 'time': 1919, 'level': 16},
#     {'ability': 5002, 'time': 2161, 'level': 17},
#     {'ability': 5002, 'time': 2237, 'level': 18},
#     {'ability': 5002, 'time': 2307, 'level': 19}],
#    'tower_damage': 3781,
#    'assists': 20,
#    'item_3': 48,
#    'last_hits': 122,
#    'item_1': 121,
#    'item_0': 36,
#    'gold_spent': 16245,
#    'item_5': 0,
#    'item_4': 185},
#   {'gold_per_min': 514,
#    'player_slot': 4,
#    'hero_damage': 17757,
#    'level': 20,
#    'account_id': nan,
#    'xp_per_min': 613,
#    'leaver_status': 0,
#    'hero_id': 71,
#    'item_2': 92,
#    'deaths': 4,
#    'gold': 3905,
#    'denies': 5,
#    'kills': 16,
#    'hero_healing': 1106,
#    'ability_upgrades': [{'ability': 5353, 'time': 203, 'level': 1},
#     {'ability': 5355, 'time': 284, 'level': 2},
#     {'ability': 5354, 'time': 317, 'level': 3},
#     {'ability': 5353, 'time': 386, 'level': 4},
#     {'ability': 5353, 'time': 442, 'level': 5},
#     {'ability': 5356, 'time': 523, 'level': 6},
#     {'ability': 5353, 'time': 660, 'level': 7},
#     {'ability': 5354, 'time': 719, 'level': 8},
#     {'ability': 5354, 'time': 781, 'level': 9},
#     {'ability': 5354, 'time': 944, 'level': 10},
#     {'ability': 5356, 'time': 1024, 'level': 11},
#     {'ability': 5355, 'time': 1193, 'level': 12},
#     {'ability': 5355, 'time': 1278, 'level': 13},
#     {'ability': 5355, 'time': 1443, 'level': 14},
#     {'ability': 5002, 'time': 1532, 'level': 15},
#     {'ability': 5356, 'time': 1664, 'level': 16},
#     {'ability': 5002, 'time': 1809, 'level': 17},
#     {'ability': 5002, 'time': 2030, 'level': 18},
#     {'ability': 5002, 'time': 2271, 'level': 19},
#     {'ability': 5002, 'time': 2354, 'level': 20}],
#    'tower_damage': 1690,
#    'assists': 17,
#    'item_3': 141,
#    'last_hits': 97,
#    'item_1': 172,
#    'item_0': 63,
#    'gold_spent': 14585,
#    'item_5': 0,
#    'item_4': 108},
#   {'gold_per_min': 316,
#    'player_slot': 128,
#    'hero_damage': 6787,
#    'level': 15,
#    'account_id': nan,
#    'xp_per_min': 346,
#    'leaver_status': 0,
#    'hero_id': 1,
#    'item_2': 21,
#    'deaths': 14,
#    'gold': 499,
#    'denies': 1,
#    'kills': 4,
#    'hero_healing': 0,
#    'ability_upgrades': [{'ability': 5004, 'time': 206, 'level': 1},
#     {'ability': 5003, 'time': 326, 'level': 2},
#     {'ability': 5003, 'time': 450, 'level': 3},
#     {'ability': 5005, 'time': 534, 'level': 4},
#     {'ability': 5003, 'time': 631, 'level': 5},
#     {'ability': 5006, 'time': 737, 'level': 6},
#     {'ability': 5005, 'time': 815, 'level': 7},
#     {'ability': 5003, 'time': 915, 'level': 8},
#     {'ability': 5004, 'time': 1096, 'level': 9},
#     {'ability': 5005, 'time': 1230, 'level': 10},
#     {'ability': 5006, 'time': 1357, 'level': 11},
#     {'ability': 5005, 'time': 1712, 'level': 12},
#     {'ability': 5004, 'time': 1888, 'level': 13},
#     {'ability': 5004, 'time': 1908, 'level': 14},
#     {'ability': 5002, 'time': 2089, 'level': 15}],
#    'tower_damage': 89,
#    'assists': 5,
#    'item_3': 71,
#    'last_hits': 116,
#    'item_1': 145,
#    'item_0': 11,
#    'gold_spent': 8830,
#    'item_5': 46,
#    'item_4': 63},
#   {'gold_per_min': 209,
#    'player_slot': 129,
#    'hero_damage': 7749,
#    'level': 12,
#    'account_id': nan,
#    'xp_per_min': 232,
#    'leaver_status': 0,
#    'hero_id': 14,
#    'item_2': 180,
#    'deaths': 7,
#    'gold': 698,
#    'denies': 4,
#    'kills': 6,
#    'hero_healing': 0,
#    'ability_upgrades': [{'ability': 5076, 'time': 249, 'level': 1},
#     {'ability': 5075, 'time': 285, 'level': 2},
#     {'ability': 5075, 'time': 335, 'level': 3},
#     {'ability': 5076, 'time': 404, 'level': 4},
#     {'ability': 5075, 'time': 472, 'level': 5},
#     {'ability': 5077, 'time': 596, 'level': 6},
#     {'ability': 5075, 'time': 737, 'level': 7},
#     {'ability': 5076, 'time': 1223, 'level': 8},
#     {'ability': 5076, 'time': 1395, 'level': 9},
#     {'ability': 5074, 'time': 1491, 'level': 10},
#     {'ability': 5077, 'time': 1717, 'level': 11},
#     {'ability': 5074, 'time': 2073, 'level': 12}],
#    'tower_damage': 0,
#    'assists': 4,
#    'item_3': 43,
#    'last_hits': 15,
#    'item_1': 41,
#    'item_0': 1,
#    'gold_spent': 6170,
#    'item_5': 42,
#    'item_4': 46},
#   {'gold_per_min': 229,
#    'player_slot': 130,
#    'hero_damage': 8740,
#    'level': 12,
#    'account_id': 149474577,
#    'xp_per_min': 233,
#    'leaver_status': 0,
#    'hero_id': 23,
#    'item_2': 36,
#    'deaths': 10,
#    'gold': 498,
#    'denies': 3,
#    'kills': 2,
#    'hero_healing': 0,
#    'ability_upgrades': [{'ability': 5032, 'time': 246, 'level': 1},
#     {'ability': 5031, 'time': 312, 'level': 2},
#     {'ability': 5032, 'time': 363, 'level': 3},
#     {'ability': 5033, 'time': 475, 'level': 4},
#     {'ability': 5032, 'time': 664, 'level': 5},
#     {'ability': 5035, 'time': 797, 'level': 6},
#     {'ability': 5033, 'time': 981, 'level': 7},
#     {'ability': 5032, 'time': 1207, 'level': 8},
#     {'ability': 5031, 'time': 1323, 'level': 9},
#     {'ability': 5031, 'time': 1527, 'level': 10},
#     {'ability': 5035, 'time': 1762, 'level': 11},
#     {'ability': 5031, 'time': 2347, 'level': 12}],
#    'tower_damage': 67,
#    'assists': 5,
#    'item_3': 5,
#    'last_hits': 64,
#    'item_1': 50,
#    'item_0': 92,
#    'gold_spent': 5500,
#    'item_5': 46,
#    'item_4': 73},
#   {'gold_per_min': 187,
#    'player_slot': 131,
#    'hero_damage': 5278,
#    'level': 11,
#    'account_id': nan,
#    'xp_per_min': 166,
#    'leaver_status': 0,
#    'hero_id': 37,
#    'item_2': 16,
#    'deaths': 13,
#    'gold': 1149,
#    'denies': 3,
#    'kills': 0,
#    'hero_healing': 1811,
#    'ability_upgrades': [{'ability': 5163, 'time': 157, 'level': 1},
#     {'ability': 5162, 'time': 317, 'level': 2},
#     {'ability': 5163, 'time': 407, 'level': 3},
#     {'ability': 5164, 'time': 630, 'level': 4},
#     {'ability': 5163, 'time': 810, 'level': 5},
#     {'ability': 5165, 'time': 1004, 'level': 6},
#     {'ability': 5163, 'time': 1201, 'level': 7},
#     {'ability': 5164, 'time': 1316, 'level': 8},
#     {'ability': 5164, 'time': 1766, 'level': 9},
#     {'ability': 5164, 'time': 2135, 'level': 10}],
#    'tower_damage': 290,
#    'assists': 10,
#    'item_3': 42,
#    'last_hits': 26,
#    'item_1': 16,
#    'item_0': 180,
#    'gold_spent': 3745,
#    'item_5': 0,
#    'item_4': 60},
#   {'gold_per_min': 342,
#    'player_slot': 132,
#    'hero_damage': 12483,
#    'level': 16,
#    'account_id': nan,
#    'xp_per_min': 371,
#    'leaver_status': 0,
#    'hero_id': 35,
#    'item_2': 166,
#    'deaths': 9,
#    'gold': 934,
#    'denies': 1,
#    'kills': 6,
#    'hero_healing': 0,
#    'ability_upgrades': [{'ability': 5156, 'time': 185, 'level': 1},
#     {'ability': 5155, 'time': 315, 'level': 2},
#     {'ability': 5154, 'time': 391, 'level': 3},
#     {'ability': 5156, 'time': 477, 'level': 4},
#     {'ability': 5156, 'time': 513, 'level': 5},
#     {'ability': 5157, 'time': 582, 'level': 6},
#     {'ability': 5156, 'time': 675, 'level': 7},
#     {'ability': 5155, 'time': 747, 'level': 8},
#     {'ability': 5155, 'time': 899, 'level': 9},
#     {'ability': 5155, 'time': 1247, 'level': 10},
#     {'ability': 5157, 'time': 1358, 'level': 11},
#     {'ability': 5154, 'time': 1895, 'level': 12},
#     {'ability': 5154, 'time': 1896, 'level': 13},
#     {'ability': 5154, 'time': 2208, 'level': 14},
#     {'ability': 5002, 'time': 2246, 'level': 15},
#     {'ability': 5157, 'time': 2317, 'level': 16}],
#    'tower_damage': 215,
#    'assists': 10,
#    'item_3': 168,
#    'last_hits': 83,
#    'item_1': 63,
#    'item_0': 212,
#    'gold_spent': 9975,
#    'item_5': 0,
#    'item_4': 0}],
#  'lobby_type': 7,
#  'cluster': 114,
#  'tower_status_radiant': 1846,
#  'game_mode': 1,
#  'positive_votes': 0,
#  'radiant_win': True,
#  'duration': 2229,
#  'leagueid': 0,
#  'negative_votes': 0,
#  'first_blood_time': 117,
#  'match_id': 550037822,
#  'tower_status_dire': 0,
#  'human_players': 10,
#  'barracks_status_radiant': 63,
#  'barracks_status_dire': 0,
#  'match_seq_num': 501037756,
#  'start_time': 1394072454}
