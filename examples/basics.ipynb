# %%
# %load_ext autoreload
# %autoreload

import arrow
import json
import os

import requests
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

from dota import api
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# supply your own API key.
with open(os.path.expanduser('~/Dropbox/bin/api-keys.txt'), 'r') as f:
    api_keys = json.load(f)

KEY = api_keys['steam']  # just a string with the key.
account_id = "76561198025007092"

h = api.API(KEY)

# %%
history = h.get_match_history(account_id=account_id)
history.partner_counts().head()
# Out:
# 64741364     158
# 142531084     49
# 36947763       2
# 145551507      2
# 86047172       2
# dtype: int64

# %%
details = history.get_all_match_details()
# Out:
# Added 550062218 (0.0%)
# Added 541698504 (10.126582278481013%)
# Added 533444058 (19.620253164556964%)
# Added 533408126 (20.253164556962027%)
# Added 525602243 (29.746835443037973%)
# Added 525553478 (30.379746835443036%)
# Added 510739148 (39.87341772151899%)
# Added 480276736 (50.0%)
# Added 471833055 (60.12658227848101%)
# Added 466847536 (69.62025316455696%)
# Added 466813579 (70.25316455696202%)
# Added 459824629 (79.74683544303798%)
# Added 459783808 (80.37974683544304%)
# Added 453225946 (89.87341772151899%)

# %%
details[526809506].match_report()
# Out:
#                                   level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 526809506 Radiant witch_doctor       17     12       1       20         49
#                   death_prophet      19     11       3        9         81
#                   phantom_lancer     18     10       1       10        208
#                   sand_king          15      3       3       21         56
#                   110                18     12       1       22         24
#           Dire    mirana             12      2       9        1         67
#                   shadow_shaman      12      0      11        4         63
#                   brewmaster         13      1       7        2         57
#                   medusa             11      1       7        2         54
#                   earthshaker        10      1      14        3         22
#
#                                   denies  gold  gold_spent  player_slot  \
# match_id  team    hero
# 526809506 Radiant witch_doctor         0  5044        9510            1
#                   death_prophet        1  3326       12495            2
#                   phantom_lancer       3  4162       17610            4
#                   sand_king            1  1309       10220            3
#                   110                  3  3272       11145            0
#           Dire    mirana               2   193        7235          128
#                   shadow_shaman        2   730        7125          129
#                   brewmaster           1   795        5480          132
#                   medusa               2   687        6170          130
#                   earthshaker          0   903        3580          131
#
#                                   account_id  item_0  item_1  item_2  item_3  \
# match_id  team    hero
# 526809506 Radiant witch_doctor           NaN     108      16     180     152
#                   death_prophet          NaN     121     102      36      48
#                   phantom_lancer    64741364     114      46      63     174
#                   sand_king        142531084     180     108      73       1
#                   110              102191207     114      92     102       0
#           Dire    mirana            87496722       0     168       0       0
#                   shadow_shaman          NaN     180      28     185      77
#                   brewmaster             NaN      50      81      16     182
#                   medusa                 NaN      24      11      50      69
#                   earthshaker            NaN      44     182      38     180
#
#                                   item_4  item_5    win
# match_id  team    hero
# 526809506 Radiant witch_doctor         0       0   True
#                   death_prophet       41       0   True
#                   phantom_lancer     147     178   True
#                   sand_king            0       0   True
#                   110                214       0   True
#           Dire    mirana               0       0  False
#                   shadow_shaman        0      69  False
#                   brewmaster          60       0  False
#                   medusa               0       0  False
#                   earthshaker         92       0  False
#
# [10 rows x 17 columns]

# %%
JOESID = 142531084
my_dota_id = api.id_32(int(account_id))
joes_steam = api.id_64(JOESID)

# %%
df = pd.concat([details[m].match_report() for m in details])
df.head()
# Out:
#                                   level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 480276736 Radiant riki               25     13      11       18         89
#                   sniper             25     17       9       13        299
#                   crystal_maiden     19      4      18        9         78
#                   lone_druid         25      7       8       14        293
#                   shredder           25      9      12       11        236
#
#                                   denies  gold  gold_spent  player_slot  \
# match_id  team    hero
# 480276736 Radiant riki                 0  1479       13961            1
#                   sniper              20  1726       25140            2
#                   crystal_maiden       0   359       11570            3
#                   lone_druid           3  1029       21054            0
#                   shredder             2  3752       19594            4
#
#                                   account_id  item_0  item_1  item_2  item_3  \
# match_id  team    hero
# 480276736 Radiant riki                   NaN     147      63     125     154
#                   sniper           122320847      63     116     168     154
#                   crystal_maiden    70170480      79      21     214       8
#                   lone_druid        64741364      36     214       0       0
#                   shredder          65048379     152     180     121     116
#
#                                   item_4  item_5    win
# match_id  team    hero
# 480276736 Radiant riki                 0       0  False
#                   sniper             141     164  False
#                   crystal_maiden       1      26  False
#                   lone_druid         182      43  False
#                   shredder           168      30  False
#
# [5 rows x 17 columns]

# %%
# my win percent
df[df.account_id == my_dota_id].win.mean()
# Out:
# 0.57594936708860756

# %%
# Win percent with Joe
df[df.account_id == JOESID].win.mean()
# Out:
# 0.53061224489795922

# %%
gr = df.groupby(level='match_id')
games = gr['account_id'].apply(lambda x:
                              (my_dota_id in x.values) &
                              (JOESID in x.values))
games = games[games].index

idx_names =  df.index.names
df = df.reset_index()
joint = df[df.match_id.isin(games)]
joint = joint.set_index(idx_names)
df = df.set_index(idx_names)

joint.head()
# Out:
#                               level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 546195205 Radiant omniknight     18      3       7       10         49
#                   weaver         20      8       7       15        142
#                   spectre        21      4      12       17        111
#                   windrunner     22     11       5       16        160
#                   viper          21      6       6       12        178
#
#                               denies  gold  gold_spent  player_slot  \
# match_id  team    hero
# 546195205 Radiant omniknight      23  3564        9005            2
#                   weaver           6  4621       15030            3
#                   spectre          4  1673       16075            0
#                   windrunner       3  4422       17385            1
#                   viper           15  3530       16935            4
#
#                               account_id  item_0  item_1  item_2  item_3  \
# match_id  team    hero
# 546195205 Radiant omniknight         NaN     180      79     178       9
#                   weaver       142531084      63     212     168      32
#                   spectre      126801707      50      11     114      65
#                   windrunner         NaN     152       7       7     141
#                   viper         64741364      50      46     185     108
#
#                               item_4  item_5   win
# match_id  team    hero
# 546195205 Radiant omniknight       0       0  True
#                   weaver         123      30  True
#                   spectre        127       0  True
#                   windrunner     164      63  True
#                   viper           52     116  True
#
# [5 rows x 17 columns]

# %%
joint.win.mean()
# Out:
# 0.5

# %%
import datetime

df.to_csv('../data/details_joined-' + datetime.datetime.now().strftime('%Y-%m-%d'))

# %%
for k, v in details.items():
    with open('../data/detail' + str(k) + '.json', 'w') as f:
        json.dump(v.resp, f)

# %%
# Joe's data

steam_id = api.id_64(142531084)
joe_hist = h.get_match_history(account_id=steam_id)
details = joe_hist.get_all_match_details()
# Out:
# Added 550037822 (0.0%)
# Added 550014092 (0.2%)
# Added 548780514 (0.4%)
# Added 530054192 (9.6%)
# Added 530034680 (9.8%)
# Added 528314084 (10.0%)
# Added 528276599 (10.2%)
# Added 526978510 (10.4%)
# Added 494192603 (19.6%)
# Added 492408049 (19.8%)
# Added 490424342 (20.0%)
# Added 488885955 (20.2%)
# Added 487444215 (20.4%)
# Added 468071052 (29.6%)
# Added 467640267 (29.8%)
# Added 466847536 (30.0%)
# Added 466813579 (30.2%)
# Added 466787253 (30.4%)
# Added 453662179 (39.6%)
# Added 453659416 (39.8%)
# Added 453626436 (40.0%)
# Added 453424938 (40.2%)
# Added 453346070 (40.4%)
# Added 434674901 (49.6%)
# Added 433379320 (49.8%)
# Added 433317133 (50.0%)
# Added 433210652 (50.2%)
# Added 433123686 (50.4%)
# Added 418395806 (59.6%)
# Added 417495200 (59.8%)
# Added 417421662 (60.0%)
# Added 417373757 (60.2%)
# Added 417337096 (60.4%)
# Added 402121381 (69.6%)
# Added 402097237 (69.8%)
# Added 402044535 (70.0%)
# Added 402016353 (70.2%)
# Added 401111775 (70.4%)
# Added 385699276 (79.6%)
# Added 385523515 (79.8%)
# Added 385511908 (80.0%)
# Added 385454704 (80.2%)
# Added 383925673 (80.4%)
# Added 368991886 (89.6%)
# Added 368925474 (89.8%)
# Added 367903256 (90.0%)
# Added 367839135 (90.2%)
# Added 367830558 (90.4%)
# Added 354222605 (99.6%)
# Added 354220703 (99.8%)

# %%
df = details[max(details)].match_report()
df
# Out:
#                                     level  kills  deaths  assists  last_hits  \
# match_id  team    hero
# 550037822 Radiant phantom_assassin     22     18       3       14         98
#                   leshrac              20      9       6       20        122
#                   spirit_breaker       20     16       4       17         97
#                   silencer             16      4       4       10         66
#                   102                  15      4       5       17         18
#           Dire    pudge                12      6       7        4         15
#                   kunkka               12      2      10        5         64
#                   sniper               16      6       9       10         83
#                   warlock              11      0      13       10         26
#                   antimage             15      4      14        5        116
#
#                                     denies  gold  gold_spent  player_slot  \
# match_id  team    hero
# 550037822 Radiant phantom_assassin       8  2941       17615            2
#                   leshrac                0  3930       16245            3
#                   spirit_breaker         5  3905       14585            4
#                   silencer               3  4045       10560            0
#                   102                    4  2841        9100            1
#           Dire    pudge                  4   698        6170          129
#                   kunkka                 3   498        5500          130
#                   sniper                 1   934        9975          132
#                   warlock                3  1149        3745          131
#                   antimage               1   499        8830          128
#
#                                     account_id  item_0  item_1  item_2  \
# match_id  team    hero
# 550037822 Radiant phantom_assassin   142531084     145     112       0
#                   leshrac                  NaN      36     121     108
#                   spirit_breaker           NaN      63     172      92
#                   silencer                 NaN     102      36     206
#                   102                 64741364     180      36     102
#           Dire    pudge                    NaN       1      41     180
#                   kunkka             149474577      92      50      36
#                   sniper                   NaN     212      63     166
#                   warlock                  NaN     180      16      16
#                   antimage                 NaN      11     145      21
#
#                                     item_3  item_4  item_5    win
# match_id  team    hero
# 550037822 Radiant phantom_assassin      50     135       0   True
#                   leshrac               48     185       0   True
#                   spirit_breaker       141     108       0   True
#                   silencer              79      63      77   True
#                   102                   46     185       0   True
#           Dire    pudge                 43      46      42  False
#                   kunkka                 5      73      46  False
#                   sniper               168       0       0  False
#                   warlock               42      60       0  False
#                   antimage              71      63      46  False
#
# [10 rows x 17 columns]

# %%
for k, v in details.items():
    with open('../data/detail' + str(k) + '.json', 'w') as f:
        json.dump(v.resp, f)

# %%
len(details)
# Out:
# 500

# %%
df
# Out:
#                                       level  kills  deaths  assists  \
# match_id  team    hero
# 480276736 Radiant riki                   25     13      11       18
#                   sniper                 25     17       9       13
#                   crystal_maiden         19      4      18        9
#                   lone_druid             25      7       8       14
#                   shredder               25      9      12       11
#           Dire    mirana                 25      8       9       11
#                   kunkka                 25     11       8       22
#                   lion                   18      0      22        7
#                   dragon_knight          25     20       7       14
#                   bloodseeker            25     19       6        7
# 544028929 Radiant viper                  25     16       5       14
#                   zuus                   20      5      12       16
#                   lone_druid             25      7       6       19
#                   rubick                 20      2      11       19
#                   juggernaut             25     16       9       15
#           Dire    110                    21      3       9       16
#                   storm_spirit           25     13       7       14
#                   tinker                 20      6       9       14
#                   clinkz                 24     10      10       11
#                   axe                    20     10      11       11
# 546195205 Radiant omniknight             18      3       7       10
#                   weaver                 20      8       7       15
#                   spectre                21      4      12       17
#                   windrunner             22     11       5       16
#                   viper                  21      6       6       12
#           Dire    mirana                 18      4       9        8
#                   nevermore              23      6       7        7
#                   riki                   25     23       2        5
#                   shadow_demon           15      0       9        7
#                   rubick                 17      2       8        9
# 541670151 Radiant shredder               23      9       8        9
#                   razor                  20      9      11       12
#                   slardar                19      3      12       13
#                   venomancer             19     15      12       19
#                   crystal_maiden         13      1      16        6
#           Dire    furion                 25     17       5       20
#                   drow_ranger            23     13       6       12
#                   pudge                  19      2      13       19
#                   jakiro                 20      9       5       18
#                   lion                   20     15      13       12
# 539074056 Radiant furion                 25      8       9       11
#                   windrunner             20     10       9        7
#                   necrolyte              18      4      11       10
#                   disruptor              16      4      14       13
#                   venomancer             14      2      14       18
#           Dire    tiny                   23     14       6       20
#                   enigma                 20      7       9       12
#                   ancient_apparition     19      9       6       23
#                   doom_bringer           25     16       5       25
#                   110                    24      8       3       27
# 536456564 Radiant lion                   14      5      11        4
#                   bristleback            15      4       9        2
#                   viper                  20     11      12        8
#                   doom_bringer           16      2       9        4
#                   faceless_void          16      2       5        8
#           Dire    antimage               18      6       4        8
#                   drow_ranger            19      6       8       10
#                   vengefulspirit         21     10       4       16
#                   nyx_assassin           19     11       6       17
#                   furion                 23     12       2       18
#                                         ...    ...     ...      ...
#
#                                       last_hits  denies  gold  gold_spent  \
# match_id  team    hero
# 480276736 Radiant riki                       89       0  1479       13961
#                   sniper                    299      20  1726       25140
#                   crystal_maiden             78       0   359       11570
#                   lone_druid                293       3  1029       21054
#                   shredder                  236       2  3752       19594
#           Dire    mirana                    172       3  1157       19374
#                   kunkka                    325       5  1202       30944
#                   lion                       34       0  3157        5765
#                   dragon_knight             283       0  1264       28334
#                   bloodseeker               214       3   995       29985
# 544028929 Radiant viper                     235      11  2562       25315
#                   zuus                       91       1  2092       10595
#                   lone_druid                214       1  1595       25625
#                   rubick                     57       4  2000       12560
#                   juggernaut                265       0  1406       24800
#           Dire    110                       152       5   829       12415
#                   storm_spirit              173       6   322       20375
#                   tinker                    131       0   212       16760
#                   clinkz                    157       9  1346       18765
#                   axe                       131       0   393       19060
# 546195205 Radiant omniknight                 49      23  3564        9005
#                   weaver                    142       6  4621       15030
#                   spectre                   111       4  1673       16075
#                   windrunner                160       3  4422       17385
#                   viper                     178      15  3530       16935
#           Dire    mirana                     99       0   135       13500
#                   nevermore                 328      14   962       19165
#                   riki                      172       7  1555       22805
#                   shadow_demon               39       1   601        9485
#                   rubick                     31       2   391       10160
# 541670151 Radiant shredder                  139       7  1306       11775
#                   razor                     113       1   488        9580
#                   slardar                    78       0  1661        9325
#                   venomancer                 76       8   363       14115
#                   crystal_maiden             43       0   300        4780
#           Dire    furion                    257       0  5753       23160
#                   drow_ranger               177      13  9401       14075
#                   pudge                      43       0  1172       11425
#                   jakiro                     45       2   787       14735
#                   lion                       41       1  1138       13875
# 539074056 Radiant furion                    327       1  3805       20745
#                   windrunner                 92       3   504       11945
#                   necrolyte                 132       0   555       12735
#                   disruptor                  42       0   665        8280
#                   venomancer                 86       0   449       10865
#           Dire    tiny                      182      13  5586       19290
#                   enigma                    148      10  3225       15695
#                   ancient_apparition         57       3  3128       12520
#                   doom_bringer              248       6  5731       22265
#                   110                       151       8  3470       17500
# 536456564 Radiant lion                       30       4   174        6950
#                   bristleback                75       6   195        6975
#                   viper                     104       3  1414        8875
#                   doom_bringer              136       1    71       13345
#                   faceless_void             109       4   390       10035
#           Dire    antimage                   52       4   391       12175
#                   drow_ranger               113       6   679       16580
#                   vengefulspirit             42       3  1864       13880
#                   nyx_assassin               27       0   328       13560
#                   furion                    295      12  9497       20385
#                                             ...     ...   ...         ...
#
#                                       player_slot  account_id  item_0  item_1  \
# match_id  team    hero
# 480276736 Radiant riki                          1         NaN     147      63
#                   sniper                        2   122320847      63     116
#                   crystal_maiden                3    70170480      79      21
#                   lone_druid                    0    64741364      36     214
#                   shredder                      4    65048379     152     180
#           Dire    mirana                      128   148260268      63     212
#                   kunkka                      130    85520638     135      48
#                   lion                        132         NaN     180      73
#                   dragon_knight               131   102876437     112      48
#                   bloodseeker                 129         NaN      48     208
# 544028929 Radiant viper                         0    64741364      50      79
#                   zuus                          1         NaN      73     108
#                   lone_druid                    3         NaN     125     139
#                   rubick                        2         NaN     102     180
#                   juggernaut                    4         NaN     208      50
#           Dire    110                         128         NaN      79     127
#                   storm_spirit                131         NaN     121      63
#                   tinker                      132         NaN     178      48
#                   clinkz                      129         NaN      98     212
#                   axe                         130         NaN     214     114
# 546195205 Radiant omniknight                    2         NaN     180      79
#                   weaver                        3   142531084      63     212
#                   spectre                       0   126801707      50      11
#                   windrunner                    1         NaN     152       7
#                   viper                         4    64741364      50      46
#           Dire    mirana                      129         NaN      63     170
#                   nevermore                   131   136896429      63     147
#                   riki                        132         NaN     196      50
#                   shadow_demon                130         NaN     180     104
#                   rubick                      128         NaN     180      79
# 541670151 Radiant shredder                      0    64741364     182      46
#                   razor                         1         NaN      50      41
#                   slardar                       3         NaN      11       1
#                   venomancer                    4         NaN     100       0
#                   crystal_maiden                2         NaN      29      79
#           Dire    furion                      130         NaN     164     214
#                   drow_ranger                 128         NaN       0     152
#                   pudge                       132         NaN      50      90
#                   jakiro                      129         NaN     180     108
#                   lion                        131         NaN     202       1
# 539074056 Radiant furion                        4         NaN      63     168
#                   windrunner                    2         NaN      36       0
#                   necrolyte                     0         NaN      36      79
#                   disruptor                     3         NaN       9       0
#                   venomancer                    1    64741364      36      31
#           Dire    tiny                        130   119076832     108      48
#                   enigma                      128   117192154     180     116
#                   ancient_apparition          132         NaN      90     180
#                   doom_bringer                131    19668635      46     114
#                   110                         129    54088949     114     214
# 536456564 Radiant lion                          3         NaN     214      77
#                   bristleback                   0         NaN     127     125
#                   viper                         2   125067608       0     108
#                   doom_bringer                  1   120070849      65      88
#                   faceless_void                 4         NaN      11     172
#           Dire    antimage                    132         NaN      71      81
#                   drow_ranger                 130   109009600      63      36
#                   vengefulspirit              129   142531084     168     212
#                   nyx_assassin                128    64741364      41       0
#                   furion                      131         NaN     152      65
#                                               ...         ...     ...     ...
#
#                                       item_2  item_3  item_4  item_5    win
# match_id  team    hero
# 480276736 Radiant riki                   125     154       0       0  False
#                   sniper                 168     154     141     164  False
#                   crystal_maiden         214       8       1      26  False
#                   lone_druid               0       0     182      43  False
#                   shredder               121     116     168      30  False
#           Dire    mirana                 123     168     139      46   True
#                   kunkka                 152     114     141     112   True
#                   lion                   214     170      41      30   True
#                   dragon_knight          114     151     141      40   True
#                   bloodseeker              0     154      53     139   True
# 544028929 Radiant viper                  135      32     108      10   True
#                   zuus                    42      46      69      29   True
#                   lone_druid              50      81     143       0   True
#                   rubick                 100      88     108       0   True
#                   juggernaut             139       8     108     145   True
#           Dire    110                     56     137     214       0  False
#                   storm_spirit           123       8      98      21  False
#                   tinker                  41      96     102      23  False
#                   clinkz                  63     160      51     149  False
#                   axe                      1     127      90       0  False
# 546195205 Radiant omniknight             178       9       0       0   True
#                   weaver                 168      32     123      30   True
#                   spectre                114      65     127       0   True
#                   windrunner               7     141     164      63   True
#                   viper                  185     108      52     116   True
#           Dire    mirana                 212     168     172     149  False
#                   nevermore                1     116     164     149  False
#                   riki                   147      61     139      81  False
#                   shadow_demon            41     100      37       0  False
#                   rubick                  23      60      21      46  False
# 541670151 Radiant shredder                53     180     121       0  False
#                   razor                  154     170     212       0  False
#                   slardar                  8      73     125      63  False
#                   venomancer             108     212      63     102  False
#                   crystal_maiden          40       0      16       0  False
#           Dire    furion                 152     141     108     135   True
#                   drow_ranger             63     149     212     116   True
#                   pudge                    0     108       0       0   True
#                   jakiro                  46      79     131      31   True
#                   lion                    60      22      23     214   True
# 539074056 Radiant furion                  98     147     152       0  False
#                   windrunner              46      50      96     102  False
#                   necrolyte              201     108       0      63  False
#                   disruptor              102      79     180       0  False
#                   venomancer             102      46      29      88  False
#           Dire    tiny                     0      46     158     170   True
#                   enigma                  79       1     106      46   True
#                   ancient_apparition      34     193      40      46   True
#                   doom_bringer           137      50     112     125   True
#                   110                    119      92      30      48   True
# 536456564 Radiant lion                   108       0       0       0  False
#                   bristleback              0      16      16      63  False
#                   viper                   41      36      50      40  False
#                   doom_bringer           152      50     185       9  False
#                   faceless_void           63     145     182       3  False
#           Dire    antimage                63     170      52      10   True
#                   drow_ranger            152     154      26     141   True
#                   vengefulspirit          48     102      40      36   True
#                   nyx_assassin           203      46     180      92   True
#                   furion                  63     108     168     135   True
#                                          ...     ...     ...     ...    ...
#
# [1580 rows x 17 columns]
